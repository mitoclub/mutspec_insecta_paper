# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
blat_aa = pd.read_csv('../data/midori_Blattodea_aa_fracs.tsv', sep='\t')

# %%
# leu_frac - Leu TT
# leu2_frac Leu CT

# %%
blat_aa
# Out:
#                             Species_name  Organism Gene_name  Phe_frac  \
# 0     Acanthotermes_acanthothorax_187525  Termites        A6  0.052863
# 1     Acanthotermes_acanthothorax_187525  Termites        A8  0.094340
# 2     Acanthotermes_acanthothorax_187525  Termites       CO1  0.029183
# 3     Acanthotermes_acanthothorax_187525  Termites       CO2  0.047619
# 4     Acanthotermes_acanthothorax_187525  Termites       CO3  0.045627
# ...                                  ...       ...       ...       ...
# 5156      Zootermopsis_nevadensis_136037  Termites       ND3  0.076271
# 5157      Zootermopsis_nevadensis_136037  Termites       ND4  0.006726
# 5158      Zootermopsis_nevadensis_136037  Termites      ND4L  0.000000
# 5159      Zootermopsis_nevadensis_136037  Termites       ND5  0.006957
# 5160      Zootermopsis_nevadensis_136037  Termites       ND6  0.098765
#
#       Leu_frac  Leu2_frac  Ser_frac  Pro_frac  Cys_frac  Trp_frac  ...  \
# 0     0.017621   0.004405  0.088106  0.008811  0.083700  0.066079  ...
# 1     0.056604   0.037736  0.056604  0.000000  0.094340  0.018868  ...
# 2     0.017510   0.007782  0.145914  0.003891  0.089494  0.068093  ...
# 3     0.051948   0.012987  0.090909  0.008658  0.082251  0.073593  ...
# 4     0.034221   0.003802  0.136882  0.007605  0.121673  0.068441  ...
# ...        ...        ...       ...       ...       ...       ...  ...
# 5156  0.016949   0.016949  0.093220  0.016949  0.127119  0.059322  ...
# 5157  0.002242   0.026906  0.022422  0.047085  0.004484  0.015695  ...
# 5158  0.020833   0.041667  0.010417  0.031250  0.000000  0.010417  ...
# 5159  0.005217   0.027826  0.027826  0.038261  0.001739  0.005217  ...
# 5160  0.024691   0.006173  0.092593  0.000000  0.148148  0.067901  ...
#
#       Ser2_frac  Asp_frac  Glu_frac  Asn_frac  Lys_frac  Val_frac  Ile_frac  \
# 0      0.008811  0.088106  0.061674  0.017621  0.030837  0.101322  0.008811
# 1      0.037736  0.037736  0.075472  0.018868  0.018868  0.113208  0.056604
# 2      0.023346  0.048638  0.075875  0.036965  0.033074  0.105058  0.011673
# 3      0.012987  0.056277  0.043290  0.043290  0.004329  0.121212  0.021645
# 4      0.019011  0.049430  0.079848  0.034221  0.026616  0.106464  0.011407
# ...         ...       ...       ...       ...       ...       ...       ...
# 5156   0.008475  0.067797  0.033898  0.050847  0.050847  0.050847  0.008475
# 5157   0.123318  0.008969  0.006726  0.121076  0.141256  0.004484  0.040359
# 5158   0.072917  0.000000  0.000000  0.125000  0.177083  0.000000  0.041667
# 5159   0.146087  0.001739  0.008696  0.137391  0.165217  0.001739  0.059130
# 5160   0.012346  0.037037  0.049383  0.030864  0.012346  0.043210  0.012346
#
#       Met_frac  Ala_frac  Thr_frac
# 0     0.013216  0.022026  0.004405
# 1     0.000000  0.018868  0.000000
# 2     0.009728  0.009728  0.007782
# 3     0.017316  0.034632  0.008658
# 4     0.015209  0.011407  0.011407
# ...        ...       ...       ...
# 5156  0.008475  0.008475  0.000000
# 5157  0.060538  0.002242  0.130045
# 5158  0.104167  0.000000  0.135417
# 5159  0.055652  0.003478  0.104348
# 5160  0.030864  0.006173  0.000000
#
# [5161 rows x 25 columns]

# %%
blat_aa[blat_aa['Species_name'] == 'Acanthotermes_acanthothorax_187525']
# Out:
#                           Species_name  Organism Gene_name  Phe_frac  \
# 0   Acanthotermes_acanthothorax_187525  Termites        A6  0.052863
# 1   Acanthotermes_acanthothorax_187525  Termites        A8  0.094340
# 2   Acanthotermes_acanthothorax_187525  Termites       CO1  0.029183
# 3   Acanthotermes_acanthothorax_187525  Termites       CO2  0.047619
# 4   Acanthotermes_acanthothorax_187525  Termites       CO3  0.045627
# 5   Acanthotermes_acanthothorax_187525  Termites      Cytb  0.044974
# 6   Acanthotermes_acanthothorax_187525  Termites       ND1  0.000000
# 7   Acanthotermes_acanthothorax_187525  Termites       ND2  0.061047
# 8   Acanthotermes_acanthothorax_187525  Termites       ND3  0.084746
# 9   Acanthotermes_acanthothorax_187525  Termites       ND4  0.004464
# 10  Acanthotermes_acanthothorax_187525  Termites      ND4L  0.000000
# 11  Acanthotermes_acanthothorax_187525  Termites       ND5  0.006957
# 12  Acanthotermes_acanthothorax_187525  Termites       ND6  0.049080
#
#     Leu_frac  Leu2_frac  Ser_frac  Pro_frac  Cys_frac  Trp_frac  ...  \
# 0   0.017621   0.004405  0.088106  0.008811  0.083700  0.066079  ...
# 1   0.056604   0.037736  0.056604  0.000000  0.094340  0.018868  ...
# 2   0.017510   0.007782  0.145914  0.003891  0.089494  0.068093  ...
# 3   0.051948   0.012987  0.090909  0.008658  0.082251  0.073593  ...
# 4   0.034221   0.003802  0.136882  0.007605  0.121673  0.068441  ...
# 5   0.021164   0.005291  0.097884  0.018519  0.103175  0.066138  ...
# 6   0.006369   0.044586  0.035032  0.063694  0.000000  0.006369  ...
# 7   0.014535   0.017442  0.081395  0.002907  0.081395  0.058140  ...
# 8   0.008475   0.016949  0.110169  0.000000  0.127119  0.084746  ...
# 9   0.000000   0.029018  0.026786  0.055804  0.008929  0.008929  ...
# 10  0.020833   0.031250  0.010417  0.031250  0.000000  0.010417  ...
# 11  0.003478   0.020870  0.020870  0.064348  0.010435  0.005217  ...
# 12  0.030675   0.012270  0.061350  0.018405  0.098160  0.042945  ...
#
#     Ser2_frac  Asp_frac  Glu_frac  Asn_frac  Lys_frac  Val_frac  Ile_frac  \
# 0    0.008811  0.088106  0.061674  0.017621  0.030837  0.101322  0.008811
# 1    0.037736  0.037736  0.075472  0.018868  0.018868  0.113208  0.056604
# 2    0.023346  0.048638  0.075875  0.036965  0.033074  0.105058  0.011673
# 3    0.012987  0.056277  0.043290  0.043290  0.004329  0.121212  0.021645
# 4    0.019011  0.049430  0.079848  0.034221  0.026616  0.106464  0.011407
# 5    0.010582  0.068783  0.068783  0.026455  0.015873  0.126984  0.018519
# 6    0.136943  0.000000  0.019108  0.136943  0.184713  0.012739  0.028662
# 7    0.034884  0.043605  0.037791  0.043605  0.023256  0.066860  0.020349
# 8    0.008475  0.067797  0.067797  0.033898  0.025424  0.076271  0.008475
# 9    0.111607  0.011161  0.011161  0.111607  0.140625  0.004464  0.024554
# 10   0.072917  0.010417  0.000000  0.177083  0.156250  0.010417  0.031250
# 11   0.140870  0.006957  0.006957  0.133913  0.132174  0.005217  0.053913
# 12   0.012270  0.036810  0.012270  0.018405  0.036810  0.098160  0.012270
#
#     Met_frac  Ala_frac  Thr_frac
# 0   0.013216  0.022026  0.004405
# 1   0.000000  0.018868  0.000000
# 2   0.009728  0.009728  0.007782
# 3   0.017316  0.034632  0.008658
# 4   0.015209  0.011407  0.011407
# 5   0.013228  0.013228  0.005291
# 6   0.057325  0.015924  0.066879
# 7   0.008721  0.017442  0.017442
# 8   0.000000  0.000000  0.008475
# 9   0.071429  0.020089  0.120536
# 10  0.104167  0.000000  0.166667
# 11  0.053913  0.015652  0.086957
# 12  0.006135  0.006135  0.012270
#
# [13 rows x 25 columns]

# %%
heavy_genes = ['ND1', 'ND4', 'ND4L', 'ND5']
light_genes = ['A6', 'A8', 'CO1', 'CO2', 'CO3', 'Cytb', 'ND2', 'ND3', 'ND6']

heavy_aas = ['Asn_frac', 'Lys_frac', 'Gly_frac']
light_aas = ['Leu_frac', 'Phe_frac', 'Pro_frac']

# %%
df = blat_aa.copy()

# Если в данных бывают варианты типа "Termites w/o workers" / "Cockroaches ..."
# этот блок сведёт их к двум группам
df['Organism_group'] = np.where(
    df['Organism'].str.contains('termite', case=False, na=False),
    'Termites',
    np.where(
        df['Organism'].str.contains('cockroach', case=False, na=False),
        'Cockroaches',
        df['Organism']
    )
)

palette = {
    'Termites': 'blue',
    'Cockroaches': 'orange'
}

# --- Heavy genes ---
df_heavy = df[df['Gene_name'].isin(heavy_genes)].copy()
df_heavy_long = df_heavy.melt(
    id_vars=['Species_name', 'Organism_group', 'Gene_name'],
    value_vars=heavy_aas,
    var_name='Amino_acid',
    value_name='Fraction'
)

# --- Light genes ---
df_light = df[df['Gene_name'].isin(light_genes)].copy()
df_light_long = df_light.melt(
    id_vars=['Species_name', 'Organism_group', 'Gene_name'],
    value_vars=light_aas,
    var_name='Amino_acid',
    value_name='Fraction'
)

# --- Plot ---
fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharey=False)

sns.boxplot(
    data=df_heavy_long,
    x='Amino_acid',
    y='Fraction',
    hue='Organism_group',
    order=heavy_aas,
    hue_order=['Termites', 'Cockroaches'],
    palette=palette,
    ax=axes[0]
)

axes[0].set_title('Heavy-strand genes')
axes[0].set_xlabel('Amino acid')
axes[0].set_ylabel('Fraction')
axes[0].tick_params(axis='x', rotation=45)

sns.boxplot(
    data=df_light_long,
    x='Amino_acid',
    y='Fraction',
    hue='Organism_group',
    order=light_aas,
    hue_order=['Termites', 'Cockroaches'],
    palette=palette,
    ax=axes[1]
)

axes[1].set_title('Light-strand genes')
axes[1].set_xlabel('Amino acid')
axes[1].set_ylabel('Fraction')
axes[1].tick_params(axis='x', rotation=45)

# Чтобы легенда была только одна
axes[0].legend(title='Organism')
axes[1].get_legend().remove()

plt.tight_layout()
plt.savefig('../figures/blat_aa_boxplots.pdf')
plt.show()
plt.close()

# %%
# -----------------------------
# 1. Для light_genes: Pro / (Leu + Phe)
# -----------------------------
df_light = df[df['Gene_name'].isin(light_genes)].copy()

denom = df_light['Leu_frac'] + df_light['Phe_frac']
df_light['Pro_LeuPhe_ratio'] = np.where(
    denom > 0,
    df_light['Pro_frac'] / denom,
    np.nan
)

# -----------------------------
# 2. Для heavy_genes: Gly / (Asn + Lys)
# -----------------------------
df_heavy = df[df['Gene_name'].isin(heavy_genes)].copy()

denom = df_heavy['Asn_frac'] + df_heavy['Lys_frac']
df_heavy['Gly_AsnLys_ratio'] = np.where(
    denom > 0,
    df_heavy['Gly_frac'] / denom,
    np.nan
)

# -----------------------------
# 3. Сводка по группам
# -----------------------------
pro_leu_summary = (
    df_light.groupby('Organism_group')['Pro_LeuPhe_ratio']
    .agg(['count', 'mean', 'median', 'std', 'min', 'max'])
    .reset_index()
)

gly_asnlys_summary = (
    df_heavy.groupby('Organism_group')['Gly_AsnLys_ratio']
    .agg(['count', 'mean', 'median', 'std', 'min', 'max'])
    .reset_index()
)

print("Pro/(Leu+Phe) ratio for light genes:")
print(pro_leu_summary)
print()

print("Gly/(Asn+Lys) ratio for heavy genes:")
print(gly_asnlys_summary)
# Out:
# Pro/(Leu+Phe) ratio for light genes:
#   Organism_group  count      mean    median       std  min       max
# 0    Cockroaches    594  0.074773  0.047619  0.092040  0.0  0.666667
# 1       Termites   2979  0.163540  0.130435  0.161295  0.0  1.136364
#
# Gly/(Asn+Lys) ratio for heavy genes:
#   Organism_group  count      mean    median       std  min       max
# 0    Cockroaches    264  0.024891  0.019484  0.025384  0.0  0.157895
# 1       Termites   1324  0.048954  0.043991  0.034441  0.0  0.218487

# %% [markdown]
# # Positive genes

# %%
fracs = pd.read_csv('../data/midori_Blattodea_aa_fracs.tsv', sep = '\t')

# %%
heavy_aas = ['Asn_frac', 'Lys_frac', 'Gly_frac']
light_aas = ['Leu_frac', 'Phe_frac', 'Pro_frac']

# %%
for gene in ['ND5', 'ND4', 'ND4L', 'ND1']:
    fracs = fracs.drop(fracs[fracs['Gene_name'] == gene].index)
fracs = fracs.drop(columns=['Gene_name'])
frac_types = ['Phe_frac', 'Leu_frac',
       'Leu2_frac', 'Ser_frac', 'Pro_frac', 'Cys_frac', 'Trp_frac', 'Tyr_frac',
       'Arg_frac', 'His_frac', 'Gln_frac', 'Gly_frac', 'Ser2_frac', 'Asp_frac',
       'Glu_frac', 'Asn_frac', 'Lys_frac', 'Val_frac', 'Ile_frac', 'Met_frac',
       'Ala_frac', 'Thr_frac']

# %%
def transform_table(df, organism):
    sp_frac = {}
    sp_list = []
    frac_type_list = []
    frac_val_list = []
    for sp in df['Species_name'].unique():
        sp_list.append([sp] * len(frac_types))
        frac_type_list.append(df[df['Species_name'] == sp].drop(columns=['Species_name', 'Organism']).mean().index)
        frac_val_list.append(df[df['Species_name'] == sp].drop(columns=['Species_name', 'Organism']).mean().values)
        sp_frac[sp] = df[df['Species_name'] == sp].drop(columns=['Species_name', 'Organism']).mean()
    
    
    df = pd.DataFrame()
    for i in range(len(sp_list)):
        df = pd.concat([df, pd.DataFrame([sp_list[i], frac_type_list[i], frac_val_list[i]]).T])
    df = df.rename(columns={0:'Species_name', 1:'Frac_type', 2:'Frac_val'})
    df['Organism'] = organism
    return df

# %%
ter_fracs = fracs[fracs['Organism'] == 'Termites']
cock_fracs = fracs[fracs['Organism'] == 'Cockroaches']

cock_fracs = transform_table(cock_fracs, 'Cockroaches')
term_fracs = transform_table(ter_fracs, 'Termites')

fracs_merged = pd.concat([term_fracs, cock_fracs])

# %%
fracs_merged_heavy = fracs_merged[fracs_merged['Frac_type'].isin(heavy_aas)]

# %%
fracs_merged_heavy
# Out:
#                           Species_name Frac_type  Frac_val     Organism
# 11  Acanthotermes_acanthothorax_187525  Gly_frac  0.053913     Termites
# 15  Acanthotermes_acanthothorax_187525  Asn_frac   0.03037     Termites
# 16  Acanthotermes_acanthothorax_187525  Lys_frac  0.023898     Termites
# 11       Acholotermes_chirotus_1934430  Gly_frac  0.049487     Termites
# 15       Acholotermes_chirotus_1934430  Asn_frac  0.040628     Termites
# ..                                 ...       ...       ...          ...
# 15       Protagonista_lugubris_1844480  Asn_frac  0.106033  Cockroaches
# 16       Protagonista_lugubris_1844480  Lys_frac  0.067634  Cockroaches
# 11    Pseudoglomeris_magnifica_2813672  Gly_frac  0.033667  Cockroaches
# 15    Pseudoglomeris_magnifica_2813672  Asn_frac  0.124083  Cockroaches
# 16    Pseudoglomeris_magnifica_2813672  Lys_frac  0.070314  Cockroaches
#
# [1191 rows x 4 columns]

# %%
plt.figure(figsize=(12, 6))
ax = sns.boxplot(x='Frac_type',
                y="Frac_val",
                hue='Organism',
                data=fracs_merged_heavy)
ax.tick_params(axis='x', labelrotation=45)
plt.show()
plt.close()

# %%
fracs = pd.read_csv('../data/midori_Blattodea_aa_fracs.tsv', sep = '\t')
for gene in ['A6', 'A8', 'CO1', 'CO2', 'CO3', 'Cytb', 'ND2', 'ND3', 'ND6']:
    fracs = fracs.drop(fracs[fracs['Gene_name'] == gene].index)
fracs = fracs.drop(columns=['Gene_name'])
frac_types = ['Phe_frac', 'Leu_frac',
       'Leu2_frac', 'Ser_frac', 'Pro_frac', 'Cys_frac', 'Trp_frac', 'Tyr_frac',
       'Arg_frac', 'His_frac', 'Gln_frac', 'Gly_frac', 'Ser2_frac', 'Asp_frac',
       'Glu_frac', 'Asn_frac', 'Lys_frac', 'Val_frac', 'Ile_frac', 'Met_frac',
       'Ala_frac', 'Thr_frac']

ter_fracs = fracs[fracs['Organism'] == 'Termites']
cock_fracs = fracs[fracs['Organism'] == 'Cockroaches']

cock_fracs = transform_table(cock_fracs, 'Cockroaches')
term_fracs = transform_table(ter_fracs, 'Termites')

fracs_merged = pd.concat([term_fracs, cock_fracs])

fracs_merged_light = fracs_merged[fracs_merged['Frac_type'].isin(light_aas)]

# %%
fracs_merged_heavy
# Out:
#                           Species_name Frac_type  Frac_val     Organism
# 11  Acanthotermes_acanthothorax_187525  Gly_frac  0.053913     Termites
# 15  Acanthotermes_acanthothorax_187525  Asn_frac   0.03037     Termites
# 16  Acanthotermes_acanthothorax_187525  Lys_frac  0.023898     Termites
# 11       Acholotermes_chirotus_1934430  Gly_frac  0.049487     Termites
# 15       Acholotermes_chirotus_1934430  Asn_frac  0.040628     Termites
# ..                                 ...       ...       ...          ...
# 15       Protagonista_lugubris_1844480  Asn_frac  0.106033  Cockroaches
# 16       Protagonista_lugubris_1844480  Lys_frac  0.067634  Cockroaches
# 11    Pseudoglomeris_magnifica_2813672  Gly_frac  0.033667  Cockroaches
# 15    Pseudoglomeris_magnifica_2813672  Asn_frac  0.124083  Cockroaches
# 16    Pseudoglomeris_magnifica_2813672  Lys_frac  0.070314  Cockroaches
#
# [1191 rows x 4 columns]

# %%
palette = {
    'Termites': 'blue',
    'Cockroaches': 'orange'
}

# --- Plot ---
fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharey=False)

sns.boxplot(
    data=fracs_merged_heavy,
    x='Frac_type',
    y='Frac_val',
    hue='Organism',
    order=heavy_aas,
    hue_order=['Termites', 'Cockroaches'],
    palette=palette,
    ax=axes[0]
)

axes[0].set_title('Heavy-strand genes')
axes[0].set_xlabel('Amino acid')
axes[0].set_ylabel('Fraction')
axes[0].tick_params(axis='x', rotation=45)

sns.boxplot(
    data=fracs_merged_light,
    x='Frac_type',
    y='Frac_val',
    hue='Organism',
    order=light_aas,
    hue_order=['Termites', 'Cockroaches'],
    palette=palette,
    ax=axes[1]
)

axes[1].set_title('Light-strand genes')
axes[1].set_xlabel('Amino acid')
axes[1].set_ylabel('Fraction')
axes[1].tick_params(axis='x', rotation=45)

# Чтобы легенда была только одна
axes[0].legend(title='Organism')
axes[1].get_legend().remove()

plt.tight_layout()
plt.savefig('../figures/blat_aa_boxplots.pdf')
plt.show()
plt.close()

# %%
# -----------------------------
# HEAVY: Gly / (Asn + Lys)
# -----------------------------
heavy_ratio = (
    fracs_merged_heavy
    .pivot_table(
        index=['Species_name', 'Organism'],
        columns='Frac_type',
        values='Frac_val',
        aggfunc='first'   # если дубликатов нет
    )
    .reset_index()
)

heavy_ratio.columns.name = None

heavy_ratio['Gly_AsnLys_ratio'] = np.where(
    (heavy_ratio['Asn_frac'] + heavy_ratio['Lys_frac']) > 0,
    heavy_ratio['Gly_frac'] / (heavy_ratio['Asn_frac'] + heavy_ratio['Lys_frac']),
    np.nan
)

print("Heavy table with amino acid values and ratio:")
print(heavy_ratio[['Species_name', 'Organism', 'Gly_frac', 'Asn_frac', 'Lys_frac', 'Gly_AsnLys_ratio']])
print()

heavy_summary = (
    heavy_ratio
    .groupby('Organism')[['Gly_frac', 'Asn_frac', 'Lys_frac', 'Gly_AsnLys_ratio']]
    .agg(['count', 'mean', 'median', 'std', 'min', 'max'])
    .round(4)
)

print("Heavy summary by group:")
print(heavy_summary)
print()


# -----------------------------
# LIGHT: Pro / (Leu + Phe)
# -----------------------------
light_ratio = (
    fracs_merged_light
    .pivot_table(
        index=['Species_name', 'Organism'],
        columns='Frac_type',
        values='Frac_val',
        aggfunc='first'   # если дубликатов нет
    )
    .reset_index()
)

light_ratio.columns.name = None

light_ratio['Pro_LeuPhe_ratio'] = np.where(
    (light_ratio['Leu_frac'] + light_ratio['Phe_frac']) > 0,
    light_ratio['Pro_frac'] / (light_ratio['Leu_frac'] + light_ratio['Phe_frac']),
    np.nan
)

print("Light table with amino acid values and ratio:")
print(light_ratio[['Species_name', 'Organism', 'Pro_frac', 'Leu_frac', 'Phe_frac', 'Pro_LeuPhe_ratio']])
print()

light_summary = (
    light_ratio
    .groupby('Organism')[['Pro_frac', 'Leu_frac', 'Phe_frac', 'Pro_LeuPhe_ratio']]
    .agg(['count', 'mean', 'median', 'std', 'min', 'max'])
    .round(4)
)

print("Light summary by group:")
print(light_summary)
# Out:
# Heavy table with amino acid values and ratio:
#                            Species_name  Organism  Gly_frac  Asn_frac  \
# 0    Acanthotermes_acanthothorax_187525  Termites  0.053913  0.030370
# 1         Acholotermes_chirotus_1934430  Termites  0.049487  0.040628
# 2      Aciculitermes_aciculatus_1934431  Termites  0.037477  0.050240
# 3      Aciculitermes_maymyoensis_229658  Termites  0.046941  0.048626
# 4            Acidnotermes_praus_1934432  Termites  0.037735  0.046824
# ..                                  ...       ...       ...       ...
# 392      Tumulitermes_pastinator_286182  Termites  0.052713  0.043973
# 393       Tumulitermes_recalvus_1934613  Termites  0.047250  0.049451
# 394    Verrucositermes_tuberosus_378004  Termites  0.034821  0.053803
# 395     Zootermopsis_angusticollis_7503  Termites  0.038295  0.040853
# 396      Zootermopsis_nevadensis_136037  Termites  0.032704  0.049969
#
#      Lys_frac  Gly_AsnLys_ratio
# 0    0.023898          0.993460
# 1    0.029699          0.703662
# 2    0.044445          0.395807
# 3    0.032094          0.581528
# 4    0.038420          0.442673
# ..        ...               ...
# 392  0.029318          0.719222
# 393  0.026851          0.619253
# 394  0.027739          0.427031
# 395  0.033681          0.513796
# 396  0.034015          0.389409
#
# [397 rows x 6 columns]
#
# Heavy summary by group:
#             Gly_frac                                         Asn_frac          \
#                count    mean  median     std     min     max    count    mean
# Organism
# Cockroaches       66  0.0267  0.0260  0.0106  0.0090  0.0564       66  0.1031
# Termites         331  0.0443  0.0433  0.0093  0.0144  0.0760      331  0.0472
#
#                              ... Lys_frac                          \
#              median     std  ...   median     std     min     max
# Organism                     ...
# Cockroaches  0.1063  0.0215  ...   0.0670  0.0205  0.0349  0.1020
# Termites     0.0481  0.0109  ...   0.0303  0.0075  0.0126  0.0531
#
#             Gly_AsnLys_ratio
#                        count    mean  median     std     min     max
# Organism
# Cockroaches               66  0.1575  0.1474  0.0529  0.0473  0.3252
# Termites                 331  0.6217  0.5701  0.2671  0.1110  1.9342
#
# [2 rows x 24 columns]
#
# Light table with amino acid values and ratio:
#                            Species_name  Organism  Pro_frac  Leu_frac  \
# 0    Acanthotermes_acanthothorax_187525  Termites  0.053774  0.007670
# 1         Acholotermes_chirotus_1934430  Termites  0.033251  0.010597
# 2      Aciculitermes_aciculatus_1934431  Termites  0.035950  0.015040
# 3      Aciculitermes_maymyoensis_229658  Termites  0.043756  0.011479
# 4            Acidnotermes_praus_1934432  Termites  0.035663  0.010853
# ..                                  ...       ...       ...       ...
# 392      Tumulitermes_pastinator_286182  Termites  0.055448  0.010292
# 393       Tumulitermes_recalvus_1934613  Termites  0.036632  0.011864
# 394    Verrucositermes_tuberosus_378004  Termites  0.039066  0.012260
# 395     Zootermopsis_angusticollis_7503  Termites  0.033515  0.009897
# 396      Zootermopsis_nevadensis_136037  Termites  0.041092  0.008666
#
#      Phe_frac  Pro_LeuPhe_ratio
# 0    0.002855          5.108939
# 1    0.009004          1.696357
# 2    0.012012          1.328905
# 3    0.010779          1.965824
# 4    0.003896          2.417990
# ..        ...               ...
# 392  0.004991          3.628051
# 393  0.007326          1.908898
# 394  0.012521          1.576480
# 395  0.006570          2.035419
# 396  0.003421          3.399851
#
# [397 rows x 6 columns]
#
# Light summary by group:
#             Pro_frac                                         Leu_frac          \
#                count    mean  median     std     min     max    count    mean
# Organism
# Cockroaches       66  0.0185  0.0188  0.0070  0.0072  0.0381       66  0.0137
# Termites         331  0.0406  0.0403  0.0083  0.0186  0.0634      331  0.0091
#
#                              ... Phe_frac                          \
#              median     std  ...   median     std     min     max
# Organism                     ...
# Cockroaches  0.0139  0.0017  ...   0.0302  0.0062  0.0089  0.0427
# Termites     0.0092  0.0022  ...   0.0072  0.0041  0.0005  0.0259
#
#             Pro_LeuPhe_ratio
#                        count    mean  median     std     min      max
# Organism
# Cockroaches               66  0.4642  0.4353  0.2684  0.1485   1.8639
# Termites                 331  2.8082  2.4489  1.7175  0.4809  14.8912
#
# [2 rows x 24 columns]

# %%
df['Gene_name'] = df['Gene_name'].replace({'CYTB': 'Cytb'})

# оставим только нужные гены
df = df[df['Gene_name'].isin(heavy_genes + light_genes)].copy()

# -----------------------------
# 1. LIGHT: Pro / (Leu + Phe)
#    по каждому гену и группе
# -----------------------------
light_gene_table = (
    df[df['Gene_name'].isin(light_genes)]
    .groupby(['Organism', 'Gene_name'])[['Pro_frac', 'Leu_frac', 'Phe_frac']]
    .mean()
    .reset_index()
)

light_gene_table['Ratio_type'] = 'Pro/(Leu+Phe)'
light_gene_table['Gene_ratio'] = np.where(
    (light_gene_table['Leu_frac'] + light_gene_table['Phe_frac']) > 0,
    light_gene_table['Pro_frac'] / (light_gene_table['Leu_frac'] + light_gene_table['Phe_frac']),
    np.nan
)

# -----------------------------
# 2. HEAVY: Gly / (Asn + Lys)
#    по каждому гену и группе
# -----------------------------
heavy_gene_table = (
    df[df['Gene_name'].isin(heavy_genes)]
    .groupby(['Organism', 'Gene_name'])[['Gly_frac', 'Asn_frac', 'Lys_frac']]
    .mean()
    .reset_index()
)

heavy_gene_table['Ratio_type'] = 'Gly/(Asn+Lys)'
heavy_gene_table['Gene_ratio'] = np.where(
    (heavy_gene_table['Asn_frac'] + heavy_gene_table['Lys_frac']) > 0,
    heavy_gene_table['Gly_frac'] / (heavy_gene_table['Asn_frac'] + heavy_gene_table['Lys_frac']),
    np.nan
)

# -----------------------------
# 3. объединяем в одну таблицу
# -----------------------------
light_gene_table['Gene_class'] = 'light'
heavy_gene_table['Gene_class'] = 'heavy'

ratio_by_gene = pd.concat([
    light_gene_table[['Organism', 'Gene_name', 'Gene_class', 'Ratio_type',
                      'Pro_frac', 'Leu_frac', 'Phe_frac', 'Gene_ratio']],
    heavy_gene_table[['Organism', 'Gene_name', 'Gene_class', 'Ratio_type',
                      'Gly_frac', 'Asn_frac', 'Lys_frac', 'Gene_ratio']]
], ignore_index=True)

print(ratio_by_gene)
# Out:
#        Organism Gene_name Gene_class     Ratio_type  Pro_frac  Leu_frac  \
# 0   Cockroaches        A6      light  Pro/(Leu+Phe)  0.003875  0.024024
# 1   Cockroaches        A8      light  Pro/(Leu+Phe)  0.001743  0.042339
# 2   Cockroaches       CO1      light  Pro/(Leu+Phe)  0.008636  0.021096
# 3   Cockroaches       CO2      light  Pro/(Leu+Phe)  0.004750  0.030388
# 4   Cockroaches       CO3      light  Pro/(Leu+Phe)  0.006606  0.036420
# 5   Cockroaches      Cytb      light  Pro/(Leu+Phe)  0.007432  0.025248
# 6   Cockroaches       ND2      light  Pro/(Leu+Phe)  0.006308  0.020152
# 7   Cockroaches       ND3      light  Pro/(Leu+Phe)  0.004406  0.013342
# 8   Cockroaches       ND6      light  Pro/(Leu+Phe)  0.003110  0.039020
# 9      Termites        A6      light  Pro/(Leu+Phe)  0.009262  0.020139
# 10     Termites        A8      light  Pro/(Leu+Phe)  0.001492  0.064571
# 11     Termites       CO1      light  Pro/(Leu+Phe)  0.016622  0.016814
# 12     Termites       CO2      light  Pro/(Leu+Phe)  0.009067  0.042691
# 13     Termites       CO3      light  Pro/(Leu+Phe)  0.014728  0.034988
# 14     Termites      Cytb      light  Pro/(Leu+Phe)  0.013365  0.022389
# 15     Termites       ND2      light  Pro/(Leu+Phe)  0.014857  0.018471
# 16     Termites       ND3      light  Pro/(Leu+Phe)  0.009372  0.014497
# 17     Termites       ND6      light  Pro/(Leu+Phe)  0.008380  0.028564
# 18  Cockroaches       ND1      heavy  Gly/(Asn+Lys)       NaN       NaN
# 19  Cockroaches       ND4      heavy  Gly/(Asn+Lys)       NaN       NaN
# 20  Cockroaches      ND4L      heavy  Gly/(Asn+Lys)       NaN       NaN
# 21  Cockroaches       ND5      heavy  Gly/(Asn+Lys)       NaN       NaN
# 22     Termites       ND1      heavy  Gly/(Asn+Lys)       NaN       NaN
# 23     Termites       ND4      heavy  Gly/(Asn+Lys)       NaN       NaN
# 24     Termites      ND4L      heavy  Gly/(Asn+Lys)       NaN       NaN
# 25     Termites       ND5      heavy  Gly/(Asn+Lys)       NaN       NaN
#
#     Phe_frac  Gene_ratio  Gly_frac  Asn_frac  Lys_frac
# 0   0.036313    0.064225       NaN       NaN       NaN
# 1   0.105540    0.011785       NaN       NaN       NaN
# 2   0.034089    0.156486       NaN       NaN       NaN
# 3   0.062241    0.051283       NaN       NaN       NaN
# 4   0.038138    0.088598       NaN       NaN       NaN
# 5   0.036403    0.120545       NaN       NaN       NaN
# 6   0.054516    0.084475       NaN       NaN       NaN
# 7   0.089693    0.042767       NaN       NaN       NaN
# 8   0.056648    0.032510       NaN       NaN       NaN
# 9   0.044735    0.142763       NaN       NaN       NaN
# 10  0.094552    0.009376       NaN       NaN       NaN
# 11  0.028283    0.368601       NaN       NaN       NaN
# 12  0.057681    0.090333       NaN       NaN       NaN
# 13  0.040319    0.195566       NaN       NaN       NaN
# 14  0.037060    0.224810       NaN       NaN       NaN
# 15  0.059257    0.191145       NaN       NaN       NaN
# 16  0.085054    0.094146       NaN       NaN       NaN
# 17  0.052638    0.103200       NaN       NaN       NaN
# 18       NaN    0.020618  0.005542  0.118718  0.150092
# 19       NaN    0.028860  0.006166  0.101396  0.112264
# 20       NaN    0.017421  0.004923  0.130958  0.151634
# 21       NaN    0.027187  0.006393  0.118391  0.116774
# 22       NaN    0.045387  0.013478  0.127506  0.169452
# 23       NaN    0.062431  0.016390  0.116335  0.146193
# 24       NaN    0.024735  0.007360  0.140017  0.157551
# 25       NaN    0.060753  0.015336  0.125688  0.126745

# %%
ratio_by_gene.to_csv('../data/ratio_by_gene.csv', index=False)

# %%
heavy_genes = ['ND1', 'ND4', 'ND4L', 'ND5']
light_genes = ['A6', 'A8', 'CO1', 'CO2', 'CO3', 'Cytb', 'ND2', 'ND3', 'ND6']

gene_order = ['ND2', 'CO1', 'CO2', 'A8', 'A6', 'CO3', 'ND3', 'ND5', 'ND4', 'ND4L', 'ND6', 'Cytb', 'ND1']

df = blat_aa.copy()
df['Gene_name'] = df['Gene_name'].replace({'CYTB': 'Cytb'})

df['Organism_group'] = np.where(
    df['Organism'].str.contains('termite', case=False, na=False),
    'Termites',
    np.where(
        df['Organism'].str.contains('cockroach', case=False, na=False),
        'Cockroaches',
        df['Organism']
    )
)

df = df[df['Organism_group'].isin(['Termites', 'Cockroaches'])].copy()

# -----------------------------
# ratio by gene for LIGHT
# -----------------------------
light_ratio_by_gene = (
    df[df['Gene_name'].isin(light_genes)]
    .groupby(['Organism_group', 'Gene_name'])[['Pro_frac', 'Leu_frac', 'Phe_frac']]
    .mean()
    .reset_index()
)

light_ratio_by_gene['Gene_ratio'] = np.where(
    (light_ratio_by_gene['Leu_frac'] + light_ratio_by_gene['Phe_frac']) > 0,
    light_ratio_by_gene['Pro_frac'] / (light_ratio_by_gene['Leu_frac'] + light_ratio_by_gene['Phe_frac']),
    np.nan
)

# -----------------------------
# ratio by gene for HEAVY
# -----------------------------
heavy_ratio_by_gene = (
    df[df['Gene_name'].isin(heavy_genes)]
    .groupby(['Organism_group', 'Gene_name'])[['Gly_frac', 'Asn_frac', 'Lys_frac']]
    .mean()
    .reset_index()
)

heavy_ratio_by_gene['Gene_ratio'] = np.where(
    (heavy_ratio_by_gene['Asn_frac'] + heavy_ratio_by_gene['Lys_frac']) > 0,
    heavy_ratio_by_gene['Gly_frac'] / (heavy_ratio_by_gene['Asn_frac'] + heavy_ratio_by_gene['Lys_frac']),
    np.nan
)

# правильный порядок отдельно
light_order = [g for g in gene_order if g in light_genes]
heavy_order = [g for g in gene_order if g in heavy_genes]

# задаём категориальный порядок
light_ratio_by_gene['Gene_name'] = pd.Categorical(
    light_ratio_by_gene['Gene_name'],
    categories=light_order,
    ordered=True
)
light_ratio_by_gene = light_ratio_by_gene.sort_values('Gene_name')

heavy_ratio_by_gene['Gene_name'] = pd.Categorical(
    heavy_ratio_by_gene['Gene_name'],
    categories=heavy_order,
    ordered=True
)
heavy_ratio_by_gene = heavy_ratio_by_gene.sort_values('Gene_name')

palette = {
    'Termites': 'blue',
    'Cockroaches': 'orange'
}

# -----------------------------
# LIGHT plot
# -----------------------------
plt.figure(figsize=(10, 6))
ax = sns.lineplot(
    data=light_ratio_by_gene,
    x='Gene_name',
    y='Gene_ratio',
    hue='Organism_group',
    hue_order=['Termites', 'Cockroaches'],
    marker='o',
    linewidth=2,
    palette=palette
)

ax.set_title('Pro / (Leu + Phe) ratio by gene (light genes)')
ax.set_xlabel('Gene name')
ax.set_ylabel('Mean ratio')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../figures/light_ratio_by_gene.pdf')
plt.show()
plt.close()

# -----------------------------
# HEAVY plot
# -----------------------------
plt.figure(figsize=(8, 6))
ax = sns.lineplot(
    data=heavy_ratio_by_gene,
    x='Gene_name',
    y='Gene_ratio',
    hue='Organism_group',
    hue_order=['Termites', 'Cockroaches'],
    marker='o',
    linewidth=2,
    palette=palette
)

ax.set_title('Gly / (Asn + Lys) ratio by gene (heavy genes)')
ax.set_xlabel('Gene name')
ax.set_ylabel('Mean ratio')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../figures/heavy_ratio_by_gene.pdf')
plt.show()
plt.close()

# %%
light_ratio_by_gene
# Out:
#    Organism_group Gene_name  Pro_frac  Leu_frac  Phe_frac  Gene_ratio
# 15       Termites       ND2  0.014857  0.018471  0.059257    0.191145
# 6     Cockroaches       ND2  0.006308  0.020152  0.054516    0.084475
# 2     Cockroaches       CO1  0.008636  0.021096  0.034089    0.156486
# 11       Termites       CO1  0.016622  0.016814  0.028283    0.368601
# 3     Cockroaches       CO2  0.004750  0.030388  0.062241    0.051283
# 12       Termites       CO2  0.009067  0.042691  0.057681    0.090333
# 1     Cockroaches        A8  0.001743  0.042339  0.105540    0.011785
# 10       Termites        A8  0.001492  0.064571  0.094552    0.009376
# 0     Cockroaches        A6  0.003875  0.024024  0.036313    0.064225
# 9        Termites        A6  0.009262  0.020139  0.044735    0.142763
# 4     Cockroaches       CO3  0.006606  0.036420  0.038138    0.088598
# 13       Termites       CO3  0.014728  0.034988  0.040319    0.195566
# 7     Cockroaches       ND3  0.004406  0.013342  0.089693    0.042767
# 16       Termites       ND3  0.009372  0.014497  0.085054    0.094146
# 8     Cockroaches       ND6  0.003110  0.039020  0.056648    0.032510
# 17       Termites       ND6  0.008380  0.028564  0.052638    0.103200
# 5     Cockroaches      Cytb  0.007432  0.025248  0.036403    0.120545
# 14       Termites      Cytb  0.013365  0.022389  0.037060    0.224810
